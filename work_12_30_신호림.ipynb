# %% [markdown]
# <a href="https://colab.research.google.com/github/alkgjldsdfslk/1230/blob/main/work_12_30_%EC%8B%A0%ED%98%B8%EB%A6%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FILE_NAME='data.txt'
with open(FILE_NAME,mode='w',encoding='utf-8') as w:
    w.write('\"Happy New Year 2023! Good - Luck\"\n\"Happy New Year 2023! Good - Luck\"\n\"Happy New Year 2023! Good - Luck\"\n\"새해 복 많이 받으세요~\"\n"새해 복 많이 받으세요~\"\n"새해 복 많이 받으세요~\"\n\"1234567891011121314151617181920\"\n\"2122232425262728293031323334353637383940\"\n\"4142434445464748495051525354555657585960\"\n')

with open(FILE_NAME,mode='r',encoding='utf-8') as r:
    text=r.read()

print(text)
# Out:
# "Happy New Year 2023! Good - Luck"
# "Happy New Year 2023! Good - Luck"
# "Happy New Year 2023! Good - Luck"
# "새해 복 많이 받으세요~"
# "새해 복 많이 받으세요~"
# "새해 복 많이 받으세요~"
# "1234567891011121314151617181920"
# "2122232425262728293031323334353637383940"
# "4142434445464748495051525354555657585960"

# %%
FILE_NAME='data.txt'
with open(FILE_NAME,mode='r',encoding='utf-8') as r:
    text=r.read()

FILE_NAME='hex_data.txt'
with open(FILE_NAME,mode='w',encoding='utf-8') as w:
    for i in text:
        w.write(i if i =='\n' else hex(ord(i)))

with open(FILE_NAME,mode='r',encoding='utf-8') as r:
    print(r.read())
# Out:
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# 0x220x310x320x330x340x350x360x370x380x390x310x300x310x310x310x320x310x330x310x340x310x350x310x360x310x370x310x380x310x390x320x300x22
# 0x220x320x310x320x320x320x330x320x340x320x350x320x360x320x370x320x380x320x390x330x300x330x310x330x320x330x330x330x340x330x350x330x360x330x370x330x380x330x390x340x300x22
# 0x220x340x310x340x320x340x330x340x340x340x350x340x360x340x370x340x380x340x390x350x300x350x310x350x320x350x330x350x340x350x350x350x360x350x370x350x380x350x390x360x300x22

# %%
FILE_NAME='data.txt'
fp=open(FILE_NAME, mode='r',encoding='utf-8')
line=fp.readlines()
fp.close()
i=0
while True:
    print(*line[i:i+3])
    입력=input('+ 입력시 3줄 더 출력 : ')
    if 입력=='+': i=i+3
    else: break
    if i==9: i=0
# Out:
# "Happy New Year 2023! Good - Luck"
#  "Happy New Year 2023! Good - Luck"
#  "Happy New Year 2023! Good - Luck"
#
# + 입력시 3줄 더 출력 :

# %%
FILE_NAME1='data.txt'
FILE_NAME2='hex_data.txt'
FILE_NAME3='all_data.txt'
with open(FILE_NAME1, mode='r',encoding='utf-8') as r1:
    read1=r1.readlines()
    with open(FILE_NAME2, mode='r',encoding='utf-8') as r2:
        read2=r2.readlines()
        with open(FILE_NAME3, mode='w',encoding='utf-8') as w:
            for i in range(len(read1)):
                w.write(read1[i]+read2[i])
with open(FILE_NAME3,mode='r',encoding='utf-8') as f:
    print(f.read())
# Out:
# "Happy New Year 2023! Good - Luck"
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# "Happy New Year 2023! Good - Luck"
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# "Happy New Year 2023! Good - Luck"
# 0x220x480x610x700x700x790x200x4e0x650x770x200x590x650x610x720x200x320x300x320x330x210x200x470x6f0x6f0x640x200x2d0x200x4c0x750x630x6b0x22
# "새해 복 많이 받으세요~"
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# "새해 복 많이 받으세요~"
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# "새해 복 많이 받으세요~"
# 0x220xc0c80xd5740x200xbcf50x200xb9ce0xc7740x200xbc1b0xc73c0xc1380xc6940x7e0x22
# "1234567891011121314151617181920"
# 0x220x310x320x330x340x350x360x370x380x390x310x300x310x310x310x320x310x330x310x340x310x350x310x360x310x370x310x380x310x390x320x300x22
# "2122232425262728293031323334353637383940"
# 0x220x320x310x320x320x320x330x320x340x320x350x320x360x320x370x320x380x320x390x330x300x330x310x330x320x330x330x330x340x330x350x330x360x330x370x330x380x330x390x340x300x22
# "4142434445464748495051525354555657585960"
# 0x220x340x310x340x320x340x330x340x340x340x350x340x360x340x370x340x380x340x390x350x300x350x310x350x320x350x330x350x340x350x350x350x360x350x370x350x380x350x390x360x300x22

# %%
# 5)
# 파일명 : input.data
# - 기능 : 사용자로부터 메시지를 입력 받습니다.
#          사용자가 종료(x)를 원할 때 까지 계속 입력 받습니다.
#          입력 받은 내용을 파일에 저장하세요.

# %%
FILE_NAME='input.data'
fp=open(FILE_NAME,mode='w',encoding='utf-8')
while True:
  입력=input('입력 : ')
  if 입력=='x': break
  fp.write(입력)
  fp.write('\n')
fp.close()
# Out:
# 입력 : hii
# 입력 : hello
# 입력 : x

# %%
fp=open(FILE_NAME,mode='r',encoding='utf-8')
print(fp.read())
fp.close()
# Out:
# hii
# hello
